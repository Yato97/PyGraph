# %%
from pygraph import *
from path_finder.dijkstra import *

# %% [markdown]
# Test de `EdgeView`

# %%
G = DiGraph(5, strict=True)
G.add_edges_from([(0,1,1), (1,3,1), (3,2,2), (3,4,5), (2,4,2), (0,2,3)])
G.view

# %%
G.edge_view(0,1).color_on(3) # Error here :TODO

# %%
G.view

# %%
mon_graphe = DiGraph(5)
mon_graphe.add_edges_from([(0,1,1), (1,3,1), (3,2,2), (3,4,5), (2,4,2), (0,2,3)])
mon_graphe.view

# %%
explo = Dijkstra(mon_graphe) # Objet Dijkstra
# Out:
# {0: 0, 1: inf, 2: inf, 3: inf, 4: inf}

# %%
explo.solve()

# %%
G1 = Graph()

# %%
G1.load_json('G1.json')

# %%
DG1 = Dijkstra(G1)
# Out:
# {0: 0, 1: inf, 2: inf, 3: inf, 4: inf, 5: inf, 6: inf, 7: inf, 8: inf}

# %%
DG1.next()

# %%
DG1.next()

# %%
DG1.next()

# %%
DG1.next()

# %%
DG1.next()

# %%
DG1.next()

# %%
DG1.next()

# %%
DG1.next()

# %%
DG1.next()

# %%
DG1.next()

# %%
DG1.next()
# Out:
# Dijkstra résolu

# %%
DG1.next()
# Out:
# Dijkstra résolu

# %%
DG1.end
# Out:
# 8

# %%
DG2 = Dijkstra(G1, inside=False)
# Out:
# {0: 0, 1: inf, 2: inf, 3: inf, 4: inf, 5: inf, 6: inf, 7: inf, 8: inf}

# %%
DG2.solve()

# %%
DG1.reset_dijkstra()
# Out:
# {0: 0, 1: inf, 2: inf, 3: inf, 4: inf, 5: inf, 6: inf, 7: inf, 8: inf}

# %%
DG1.diaporama()

# %%
G = Graph(5, random=True)
