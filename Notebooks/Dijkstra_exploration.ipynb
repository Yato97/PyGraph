# %%
from PyGraph.Pygraph import *
from PyGraph.path_finder import *

# %% [markdown]
# # Présentation des méthodes concernant l'algorithme Dijkstra du module Pygraph

# %% [markdown]
# ## I) Initialisation d'un graphe vide

# %%
G1 = Graph()

# %% [markdown]
# ## II) On importe le graphe sauvegardé au préalable au format json

# %%
G1.load_json('G1.json')
G1.view

# %% [markdown]
# ## III) Initialisation de l'objet Dijkstra sur notre graphe

# %%
DG1 = Dijkstra(G1)
# Out:
# {0: 0, 1: inf, 2: inf, 3: inf, 4: inf, 5: inf, 6: inf, 7: inf, 8: inf}

# %% [markdown]
# ## IV) Lancement de la méthode de résolution étape par étape avec la méthode next()

# %%
DG1.next()

# %%
DG1.next()

# %%
DG1.next()

# %%
DG1.next()

# %%
DG1.next()

# %%
DG1.next()

# %%
DG1.next()

# %%
DG1.next()

# %%
DG1.next()

# %%
DG1.next()

# %%
DG1.next()
# Out:
# Dijkstra résolu

# %% [markdown]
# ## V) Initialisation de l'objet Dijkstra sur notre graphe avec le paramétre inside=False

# %%
DG2 = Dijkstra(G1, inside=False)
# Out:
# {0: 0, 1: inf, 2: inf, 3: inf, 4: inf, 5: inf, 6: inf, 7: inf, 8: inf}

# %% [markdown]
# ## VI) Lancement de la méthode de résolution instantané avec la méthode solve()

# %%
DG2.solve()

# %% [markdown]
# ## VII) On réinitialise notre objet afin de lancer la méthode d'export en diaporama

# %%
DG1.reset_dijkstra()
# Out:
# {0: 0, 1: inf, 2: inf, 3: inf, 4: inf, 5: inf, 6: inf, 7: inf, 8: inf}

# %%
DG1.diaporama()

# %% [markdown]
# ## VIII) Boîte à outil

# %% [markdown]
# ### Connaitre les nœuds d'arrivé et de départ

# %%
DG1.reset_dijkstra()
# Out:
# {0: 0, 1: inf, 2: inf, 3: inf, 4: inf, 5: inf, 6: inf, 7: inf, 8: inf}

# %%
DG1.start
# Out:
# 0

# %%
DG1.end
# Out:
# 8

# %% [markdown]
# ### Vérifier que la résolution est terminée

# %%
DG1.solved
# Out:
# False
